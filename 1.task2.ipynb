# %%
#1
a1= int(input())
b1= int(input())
a2=int(input())
b2=int(input())
if(a1<9 and a2<9 and b1<9 and b2<9):
    if (a1==a2  or b1==b2):
        print("YES")
    else:
        print("NO")
else:
    print("NO")
# Out:
#  4
#  4
#  5
#  5
# NO

# %%
#2
a1=int(input())
b1= int(input())
a2=int(input())
b2=int(input())
if(a1<9 and a2<9 and b1<9 and b2<9):
    if(abs(a1-a2)==1 and abs(b1-b2)==0) or (abs(a1-a2)==0 and abs(b1-b2)==1 ) or (abs(a1-a2)==1 and abs(b1-b2)==1):
        print("YES")
    else:
        print("NO")
else:
    print("NO")
# Out:
#  4
#  4
#  5
#  5
# YES

# %%
#3
a1=int(input())
b1= int(input())
a2=int(input())
b2=int(input())
if(a1<9 and a2<9 and b1<9 and b2<9):
    if  abs(a1-a2)==abs(b1-b2)!=0:
        print("YES")
    else:
        print("NO")
# Out:
#  4
#  4
#  5
#  5
# YES

# %%
#4
a1=int(input())
b1= int(input())
a2=int(input())
b2=int(input())
if(a1<9 and a2<9 and b1<9 and b2<9):
    if abs(a1-a2) == abs(b1-b2) or a1 == a2 or b1  == b2:print("Yes")
    else: print("NO")
else:print("NO")
# Out:
#  1
#  1
#  2
#  3
# NO

# %%
#5
a1=int(input())
b1= int(input())
a2=int(input())
b2=int(input())
if(a1<9 and a2<9 and b1<9 and b2<9):
    if abs(a1-a2)==2 and abs(b1-b2)==1:
        print("YES")
    else: print("NO")
else:print("NO")
# Out:
#  1
#  1
#  1
#  4
# NO

# %%
#6
n=int(input())
m=int(input())
k=int(input())
if (k%n==0 and k/n<m) or (k%m==0 and k/m<n):
    print("YES")
else: 
    print("NO")
# Out:
#  2
#  10
#  7
# NO

# %%
#7
n=int(input())
m=int(input())
x=int(input())
y=int(input())
x1=0
y1=0
if x>n/2:x1=n-x
else:x1=x
if y>m/2:y1=m-y
else: y1=y
if(y>x):print(x)
else:print(y)
# Out:
# 23
# 52
# 8
# 43
# 8

# %%
#8
a=int(input())
b=int(input())
c=int(input())
arr=[a,b,c]
arr.sort()
print(arr)
# Out:
# 1
# 2
# 1
# [1, 1, 2]

# %%
#9
a1=int(input())
b1=int(input())
c1=int(input())
a2=int(input())
b2=int(input())
c2=int(input())
if a1*b1*c1==a2*b2*c2:print("Boxes are equal")
elif a1>=a2 and b1>=b2 and c1>=c2 and (a1*b1*c1>a2*b2*c2):print("the second box is smaller than the second one")
else: print("The first box is smaller than the second one")
# Out:
# 1
# 1
# 2
# 2
# 1
# 1
# Boxes are equal

# %%
#10
N=int(input())
for i in range(1,N,1):
    print(i**2)
    i+=1
    if(i**2>N):
        break
# Out:
# 50
# 1
# 4
# 9
# 16
# 25
# 36
# 49

# %%
#11
n=int(input())
for i in range(2,n+1):
    if n%i==0:
        print(i)
        break
# Out:
# 15
# 3

# %%
#12
n=int(input())
k=1
while(k<=n):
    if k<=n:
        print(k,end=" ")
    k*=2
# Out:
# 50
# 1 2 4 8 16 32

# %%
#13
n=1
sum=0
while(n!=0):
    n=int(input())
    sum+=n
    
print(sum-1)
# Out:
# 3
# 6
# 8
# 0
# 17

# %%
#14
n=1
arr=[]
cnt=0
while(n!=0):
    n=int(input())
    if(n>0):
        arr.append(n)
        a=max(arr)
for i in arr:
    if i==a:
        cnt+=1
print(cnt)
# Out:
# 1
# 3
# 3
# 0
# 2

# %%
#15
n=int(input())
fib0=0
fib1=1
fib2=1
i=3
fibsum=0
while(n>fibsum):
    fibsum = fib1 + fib2
    fib1 = fib2
    fib2 = fibsum
    if n == fibsum:
        print(i)

    else:
        i = i + 1
if n<fibsum:print(-1)
# Out:
# 8
# 6

# %%
#16
arr=[]
while n!=0:
    n=int(input())
    arr.append(n)
cnt=0
for i in range(1,len(arr)-1):
    if arr[i]>arr[i-1] and arr[i]>arr[i+1]:
        cnt+=1
print(cnt)
# Out:
# 1
# 2
# 1
# 2
# 1
# 0
# 2

# %%
#17
n=int(input())
arr=set(map(int,input().split()))
cnt=0
for i in arr:
    cnt+=1
print(cnt)
# Out:
# 6
# 1 1 2 2 1 1
# 2

# %%
#18
n=int(input())
arr=list(map(int,input().split()))
arr.insert(0, arr.pop())
print(arr)
# Out:
# 5
# 1 2 3 4 5
# [5, 1, 2, 3, 4]

# %%
#19
n=int(input())
a=[]
cnt=0
arr=list(map(int,input().split()))
for i in range(len(arr)):
    for j in range(len(arr)):
        if arr[i]==arr[j] and i!=j:
            cnt+=1
print(int(cnt/2))
# Out:
# 5
# 1 2 3 2 3
# 2

# %%
#20
n,m=map(int,input().split())
arr1=[]
arr2=[]
for i in range(n):
    arr1.append(0)
for i in range(m):
    x,y= map(int,input().split())
    arr2.append(x)
    arr2.append(y)
for i in range(0,len(arr2)-1,2):
    for j in  range(arr2[i],arr2[i+1]+1):
        arr1[j-1]=1
for i in arr1:
    if i==0:
        print("I",end="")
    else:
        print(".",end="")
# Out:
# 10 3
# 8 10
# 2 5
# 3 6
# I.....I...
