# %%
a1= int(input())
b1= int(input())
a2=int(input())
b2=int(input())
if(a1<9 and a2<9 and b1<9 and b2<9):
    if (a1==a2  or b1==b2):
        print("YES")
    else:
        print("NO")
else:
    print("NO")
# Out:
#  4
#  4
#  5
#  5
# NO

# %%
a1=int(input())
b1= int(input())
a2=int(input())
b2=int(input())
if(a1<9 and a2<9 and b1<9 and b2<9):
    if(abs(a1-a2)==1 and abs(b1-b2)==0) or (abs(a1-a2)==0 and abs(b1-b2)==1 ) or (abs(a1-a2)==1 and abs(b1-b2)==1):
        print("YES")
    else:
        print("NO")
else:
    print("NO")
# Out:
#  4
#  4
#  5
#  5
# YES

# %%
a1=int(input())
b1= int(input())
a2=int(input())
b2=int(input())
if(a1<9 and a2<9 and b1<9 and b2<9):
    if  abs(a1-a2)==abs(b1-b2)!=0:
        print("YES")
    else:
        print("NO")
# Out:
#  4
#  4
#  5
#  5
# YES

# %%
a1=int(input())
b1= int(input())
a2=int(input())
b2=int(input())
if(a1<9 and a2<9 and b1<9 and b2<9):
    if abs(a1-a2) == abs(b1-b2) or a1 == a2 or b1  == b2:print("Yes")
    else: print("NO")
else:print("NO")
# Out:
#  1
#  1
#  2
#  3
# NO

# %%
a1=int(input())
b1= int(input())
a2=int(input())
b2=int(input())
if(a1<9 and a2<9 and b1<9 and b2<9):
    if abs(a1-a2)==2 and abs(b1-b2)==1:
        print("YES")
    else: print("NO")
else:print("NO")
# Out:
#  1
#  1
#  1
#  4
# NO

# %%
n=int(input())
m=int(input())
k=int(input())
if (k%n==0 and k/n<m) or (k%m==0 and k/m<n):
    print("YES")
else: 
    print("NO")
# Out:
#  2
#  10
#  7
# NO

# %%
n=int(input())
m=int(input())
k=int(input())
